# %% [markdown]
# Melinda Martin
# SDEV220
# Module 3 - Lists and Functions

# %%
#7.4 Create a list called "things" with three string elements, "mozzarella", "cinderella", "salmonella"

things = ["mozzarella", "cinderella", "salmonella"]
print(things)

#7.5 Capitalize the element in things that refers to a person and then print the list. 

things[1] = things[1].capitalize()
print(things)

#Did Capitalizing change the element? 
#Yes

#7.6 make cheese element all uppercase and print list

things[0] = things[0].upper()
print(things)

#7.7 delete disease element, collect nobel prize, print list
del things [2]
print("Collect Nobel Prize")
print(things)
# Out:
# ['mozzarella', 'cinderella', 'salmonella']
# ['mozzarella', 'Cinderella', 'salmonella']
# ['MOZZARELLA', 'Cinderella', 'salmonella']
# Collect Nobel Prize
# ['MOZZARELLA', 'Cinderella']

# %%
#9.1 Define a function called good() that returns the following list: ['Harry', 'Ron', 'Hermione'].

def good():
    return ['Harry', 'Ron', 'Hermione']

#9.2 Define a generator function called get_odds() that returns the odd numbers from range(10). 
#Use a for loop to find and print the third value returned.

def get_odds():
    for i in range(10):
        if i % 2 != 0:
            yield i

count = 1
for odd in get_odds():
    if count == 3:
        print(f"Third value is: {odd}")
        break
    count += 1
# Out:
# Third value is: 5
